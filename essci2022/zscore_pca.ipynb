# %%
from csv import DictReader

with open('data/combustdb_master.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    rows = [r for r in reader]
csv_file.close()

compounds = [r for r in rows if r['properties.cetane_number.value'] != '-']
print(len(compounds))
# Out:
# 408

# %%
from alvadescpy import smiles_to_descriptors

descriptors = [smiles_to_descriptors(c['canonical_smiles']) for c in compounds]

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(descriptors)

X = df.values
for i in range(len(X)):
    for j in range(len(X[i])):
        if X[i][j] == 'na':
            X[i][j] = 0.0
X = X.astype('float32')

y = np.array([[float(c['properties.cetane_number.value'])] for c in compounds], dtype='float32')

print(X.shape, y.shape)
# Out:
# (408, 5305) (408, 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)

X_norm = scaler.transform(X)
print(X_norm.shape)
# Out:
# (408, 5305)

# %%
from sklearn.decomposition import PCA

pca = PCA(svd_solver='full', random_state=0)
pca.fit(X_norm)
X_pca = pca.transform(X_norm)
print(X_pca.shape)
# Out:
# (408, 408)

# %%
from scipy.stats import zscore

X_zscores = zscore(X_pca, axis=0)
sample_means = np.mean(X_zscores, axis=1)
sample_stds = np.std(X_zscores, axis=1)
print(X_zscores.shape)
# Out:
# (408, 408)

# %%
with open('pred_results.csv', 'r') as csv_file:
    reader = DictReader(csv_file)
    results = [r for r in reader]
csv_file.close()

pred = [float(r['pred']) for r in results]
actual = [float(r['actual']) for r in results]

abs_err = [abs(pred[i] - actual[i]) for i in range(len(pred))]
err = [pred[i] - actual[i] for i in range(len(pred))]

# %%
from matplotlib import pyplot as plt

plt.scatter(err, sample_means, color='green')
plt.xlabel('Sample Prediction Error (CN Units)')
plt.ylabel('Mean Z-Score of PCs')
plt.show()

# %%
plt.clf()
plt.scatter(abs_err, sample_means, color='green')
plt.xlabel('Sample Prediction Absolute Error (CN Units)')
plt.ylabel('Mean Z-Score of PCs')
plt.show()

# %%
plt.clf()
plt.scatter(err, sample_stds, color='red')
plt.xlabel('Sample Prediction Error (CN Units)')
plt.ylabel('Standard Deviation of Z-Scores of PCs')
plt.show()

# %%
plt.clf()
plt.scatter(abs_err, sample_stds, color='red')
plt.xlabel('Sample Prediction Absolute Error (CN Units)')
plt.ylabel('Standard Deviation of Z-Scores of PCs')
plt.show()
